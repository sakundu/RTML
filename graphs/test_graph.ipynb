# %%
import logging
from gen_graph import *

# %%
# Create a logger object
logger = logging.getLogger()

# Configure the logger to output messages to the notebook console
handler = logging.StreamHandler()
handler.setLevel(logging.DEBUG)
logger.addHandler(handler)

# %% [markdown]
# ## Generate logical hierarchy graph for Axiline

# %%
axiline_netlist = './netlists/axiline_SVM_12_4_4_1.v'
G, unique_module_count = gen_graph_from_netlist(axiline_netlist)
# Out:
# DEBUG:root:AST generation time: 2.0839731693267822s
# AST generation time: 2.0839731693267822s
# DEBUG:root:Module list generation time:1.1444091796875e-05s
# Module list generation time:1.1444091796875e-05s
# DEBUG:root:Module feature extraction time:0.003755807876586914s
# Module feature extraction time:0.003755807876586914s
# DEBUG:root:Unique module extraction time:3.5762786865234375e-05s
# Unique module extraction time:3.5762786865234375e-05s
# DEBUG:root:Create Graph runtime: 0.00017452239990234375s
# Create Graph runtime: 0.00017452239990234375s

# %%
# Set the default font size to 12
plt.rcParams.update({'font.size': 30})

plt.figure(figsize=(10,10), dpi = 600)
draw_graph(G, unique_module_count)
# Out:
# DEBUG:matplotlib.axes._base:top of axes not in the figure, so title not moved
# top of axes not in the figure, so title not moved
# DEBUG:matplotlib.font_manager:findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# ...

# %%
tabla_netlist = './netlists/tabla_design01_generic.v'
tabla_G, tabla_unique_module_count = gen_graph_from_netlist(tabla_netlist)
# Out:
# DEBUG:root:AST generation time: 78.45094585418701s
# AST generation time: 78.45094585418701s
# DEBUG:root:Module list generation time:0.0002853870391845703s
# Module list generation time:0.0002853870391845703s
# DEBUG:root:Module feature extraction time:3.9096646308898926s
# Module feature extraction time:3.9096646308898926s
# DEBUG:root:Unique module extraction time:0.03714561462402344s
# Unique module extraction time:0.03714561462402344s
# DEBUG:root:Create Graph runtime: 0.008000850677490234s
# Create Graph runtime: 0.008000850677490234s

# %%
print(tabla_unique_module_count)
# Out:
# 2262

# %%
ids = []

node_count = tabla_G.number_of_nodes()

# for i in range(node_count):
#     print(tabla_G.nodes[i]['name'])

print(tabla_G.nodes[5],'\n',tabla_G.nodes[7])
# Out:
# {'name': 'DPRFW64B32_wrap', 'input_count': 7, 'output_count': 1, 'node_id': 1, 'avg_input_bits': 6.857142857142857, 'avg_output_bits': 32.0, 'num_logic_gates': 0, 'flop_count': 0, 'avg_logic_bits': 0, 'macro_count': 1}
#  {'name': 'DPRFW64B32_wrap_49', 'input_count': 7, 'output_count': 1, 'node_id': 3, 'avg_input_bits': 6.857142857142857, 'avg_output_bits': 32.0, 'num_logic_gates': 0, 'flop_count': 0, 'avg_logic_bits': 0, 'macro_count': 1}
